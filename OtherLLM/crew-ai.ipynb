# %% [markdown]
# <center><p float="center">
#   <img src="https://mma.prnewswire.com/media/1458111/Great_Learning_Logo.jpg?p=facebook" width="200" height="100"/>
# </p></center>                                                                               <center><h1></h1></center>
# <h1><center> <font size=10>GA-NLP</font></center></h1
# <h1><center> <font size=5>Week 7: AI Assistant Development</font></center></h1
#
# <h1><center><font size=5> (Additional Content)</font></center></h1>

# %% [markdown]
# # Problem Statement

# %% [markdown]
# ### Business Context

# %% [markdown]
# In an era dominated by digital media, the demand for timely and accurate information continues to grow. Blogs and online articles serve as vital platforms for news dissemination, enabling publishers to engage audiences through diverse content. With the rapid evolution of reader preferences and the influx of information across various channels, traditional approaches to content creation and curation may fall short. Leveraging analytics and advanced research methodologies can enhance the quality and relevance of blog content, allowing publishers to effectively meet the needs of their readers while staying ahead in a competitive landscape.
#
# With tools and frameworks designed to facilitate content research, such as artificial intelligence and data analytics, organizations can efficiently explore trending topics and understand audience preferences. This presents an opportunity to not only inform and educate readers but also to establish a robust online presence and foster community engagement through high-quality blog content.

# %% [markdown]
# ### Problem Definition

# %% [markdown]
# Despite the opportunities presented by the digital landscape, several challenges hinder effective blogging practices:
#
# * **Content Saturation**: The internet is flooded with information, making it difficult for publishers to create standout content that captures audience attention amidst the noise.
# * **Understanding Audience Needs**: Accurately gauging reader preferences and interests can be challenging, leading to content that may not resonate with the target audience.
# * **Quality vs. Quantity**: Striking a balance between producing frequent content and maintaining high-quality standards is often a significant struggle for content creators.
# * **Effective Research Methods**: Traditional research techniques may be time-consuming and may not yield timely or relevant insights for developing blog topics that engage readers.
# To address these issues, there is a critical need for a systematic approach that utilizes modern research techniques and analytics to inform blog writing effectively.

# %% [markdown]
# # Objective

# %% [markdown]
# To create a content research and blog writing agent using Crew AI

# %% [markdown]
# # Importing the necessary libraries and the model

# %% [markdown]
# ## About **Crew AI**

# %% [markdown]
# **Crew AI** is an advanced artificial intelligence platform designed to enhance team collaboration and productivity by automating repetitive tasks and facilitating seamless communication across various channels. It enables organizations to optimize workflows, improve decision-making processes, and foster innovation by harnessing data-driven insights in real-time. With its intuitive interface and powerful analytics, Crew AI empowers teams to focus on strategic initiatives while minimizing administrative burdens.
#                                                                                 [Documentation](https://www.crewai.com/)
#
# ![image.png](data:image/png;base64,...)

# %%
# !pip install crewai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 918.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.2/300.2 kB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 84.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Creating Groq API Key

# %% [markdown]
# Click on this [Link](https://console.groq.com/login), and click login with Google.![image.png](data:image/png;base64,...)
#
# On logging in, you will be taken to this page.Click on "API KEYS" as highlighted.![image.png](data:image/png;base64,...)
# On clicking on API Keys, you will be landing on this page. Click On Create API Keys
# ![image.png](data:image/png;base64,...)
# Choose a suitable name for your API, for example we chose "llama-guard-api" for this case and click on submit.
# ![Screenshot 2025-01-29 115904.png](data:image/png;base64,...)
# After clicking on submit, your API key will be displayed, click on Copy.
# ![image.png](data:image/png;base64,...)
# Copy this key and paste it in google secrets

# %% [markdown]
# ## How to use google secrets

# %% [markdown]
# Click on the icon shown:-
#
# ![image.png](data:image/png;base64,...)
#
# In the Name field, enter GROQ_API_KEY. In the Value field, paste your GROQ API Key and also dont forget to toggle it so that we can access the key in this notebook.
# ![image.png](data:image/png;base64,...)

# %%
from crewai import Agent, Task, Crew
from google.colab import userdata

# %% [markdown]
# # Configuring the LLM for creating Agents

# %%
from crewai import LLM

llama3 = LLM(
    model="groq/llama3-8b-8192",
    api_key=userdata.get('QWEN_API_KEY'),

)

# %% [markdown]
# # Creating Agents

# %%
researcher = Agent(
    role="AI Researcher",
    goal="Research and summarize the top AI trends for 2025.",
    backstory="Expert in finding and summarizing the latest advancements in artificial intelligence.",
    llm=llama3
)

# %% [markdown]
# This code snippet initializes an instance of the `Agent` class, designated as an "AI Researcher." The agent's goal is to research and summarize the leading AI trends anticipated for 2025, drawing on its expertise in identifying and synthesizing the latest advancements in artificial intelligence. Additionally, it utilizes the specified language model, `llama3`, to facilitate its research and summarization tasks effectively.

# %%
writer = Agent(
    role="Content Writer",
    goal="Create a clear, engaging blog outline based on research findings.",
    backstory="Skilled at organizing information into easy-to-read blog posts.",
    llm=llama3
)

# %% [markdown]
# This code snippet creates an instance of the `Agent` class, functioning as a "Content Writer." The agent's primary goal is to develop a clear and engaging blog outline informed by the research findings on AI trends. With a backstory highlighting its proficiency in transforming complex information into easily digestible blog posts, the writer will utilize the `llama3` language model to craft a coherent and compelling outline for readers.

# %% [markdown]
# # Creating Tasks

# %% [markdown]
# In Crew AI, tasks are designed to streamline and structure the workflow by assigning specific goals to agents, ensuring focused and efficient execution of assignments. Each task includes a clear description, expected output, and the designated agent responsible for completing it, fostering collaboration and accountability within the team.

# %%
research_task = Task(
    description="Find and briefly describe the top 3 AI trends expected in 2025.",
    expected_output="A list of 3 AI trends with a 2-3 sentence summary for each.",
    agent=researcher
)

# %%
writing_task = Task(
    description="Using the researcher's findings, create a blog post outline titled 'Top 3 AI Trends to Watch in 2025' with Introduction, one section per trend, and a Conclusion.",
    expected_output="A structured blog outline with section titles and bullet points for each trend.",
    agent=writer
)

# %% [markdown]
# # Intialising Crew Agent

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, writing_task]
)

# %% [markdown]
# This code snippet initializes an instance of the `Crew` class, which organizes a team comprising the "researcher" and "writer" agents. It assigns specific tasks to each agent, including the `research_task` aimed at identifying top AI trends and the corresponding `writing_task`, facilitating collaboration within the team to ensure a cohesive approach to research and content creation.

# %%
print("Running the CrewAI workflow. Please wait...")
results = crew.kickoff()
print("\n=== Blog Outline Generated by CrewAI ===\n")
print(results)
# Out:
# Running the CrewAI workflow. Please wait...
#
# === Blog Outline Generated by CrewAI ===
#
# **Top 3 AI Trends to Watch in 2025**
#
# **Introduction**
#
# * Brief overview of AI's rapid growth and adoption in recent years
# * Explanation of why AI trends are important to watch in 2025
# * Thesis statement: As AI continues to transform industries and revolutionize the way we live and work, staying ahead of the curve requires understanding the top 3 AI trends to watch in 2025.
#
# **Section 1: Edge AI and IoT**
#
# * Definition of Edge AI and its importance in the IoT ecosystem
# * Examples of industries and applications that will benefit from Edge AI, such as:
# 	+ Smart cities and infrastructure management
# 	+ Industrial automation and predictive maintenance
# 	+ Healthcare and medical devices
# * Discussion of the challenges and opportunities in Edge AI adoption, including:
# 	+ Data security and privacy concerns
# 	+ The need for specialized hardware and software
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion, this workflow exemplifies the effective utilization of the Crew AI framework to seamlessly integrate research and content writing processes. By leveraging specialized agents—an AI researcher and a content writer—the system efficiently identifies and synthesizes critical AI trends forecasted for 2025. The resulting blog outline provides a comprehensive exploration of significant topics such as Edge AI, Explainable AI, and Human-AI Collaboration, each underscored by practical examples and potential challenges. This structured approach not only enhances the quality of the content but also empowers writers to deliver informative and engaging materials that resonate with readers, ultimately positioning organizations to stay ahead in the rapidly evolving landscape of artificial intelligence.
