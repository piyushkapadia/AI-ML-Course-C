# %% [markdown]
# # Financial Analysis with Finnhub API, Google Gemini AI, and LangChain
#
# This project leverages cutting-edge technologies to perform financial analysis and market insights. It integrates the following components:
#
# - **Finnhub API**: Fetches real-time market news and financial data.
# - **Google Gemini AI Model**: Provides advanced AI capabilities for analyzing financial trends and patterns.
# - **LangChain AI Agent**: Facilitates intelligent decision-making and natural language processing for financial queries.
#
# ## Features
# - Real-time market news aggregation.
# - AI-driven financial trend analysis.
# - Interactive financial query handling using LangChain.
#
# ## Requirements
# - Python 3.8+
# - API keys for Finnhub and Google Gemini AI.
# - Required Python libraries (see `requirements.txt`).
#
# ## Getting Started
# 1. Clone the repository.
# 2. Install dependencies using `pip install -r requirements.txt`.
# 3. Configure API keys in the `.env` file.
# 4. Run the application to start analyzing financial data.
#
# This project aims to empower users with actionable insights into financial markets using state-of-the-art AI and data integration tools.

# %% [markdown]
# Finnhub Details
#
# https://finnhub.io/dashboard
# priya_kapadia01@yahoo.com
#
# API Key d1nv329r01qtrauu4490d1nv329r01qtrauu449g
#
# Secret:
# d1nv329r01qtrauu44ag
# All requests' header made from our server will contain field "X-Finnhub-Secret": "d1nv329r01qtrauu44ag" for authentication. To acknowledge receipt of an event, your endpoint must return a 2xx HTTP status code. Acknowledge events prior to any logic that needs to take place to prevent timeouts. Your endpoint is disabled if it fails to acknowledge events over consecutive days.
#
# https://finnhub.io/pricing
#
# https://finnhub.io/docs/api/introduction
#
# https://finnhub.io/dashboard/download
#
# https://github.com/Finnhub-Stock-API/finnhub-python
#
# https://finnhub.io/docs/api/library

# %% [markdown]
# Google Gemini Details
#
# API Key AIzaSyBwFQmqOkP3T7m_M-4Hq2DEYOUssB1eFpo
# Project Number 1037508373335
#
# https://ai.google.dev/gemini-api/docs/models
#
# https://ai.google.dev/gemini-api/docs/rate-limits
#
# Rate limits are usually measured across three dimensions:
#
# Requests per minute (RPM)
# Requests per day (RPD)
# Tokens per minute (input) (TPM)
#
# Use this model
# https://ai.google.dev/gemini-api/docs/models#gemini-2.0-flash-lite

# %%
# Install all dependencies for the project.
# !pip install finnhub-python
# !pip install finnhub
# !pip install google-genai
# !pip install langchain google-generativeai
# !pip install langchain_google_genai
# !pip install google-ai-generativelanguage==0.6.18

# %%
import os
finnhub_io_api_key = 'd1nv329r01qtrauu4490d1nv329r01qtrauu449g'
google_genai_api_key = 'AIzaSyBwFQmqOkP3T7m_M-4Hq2DEYOUssB1eFpo'
google_gemini_model="gemini-2.0-flash-lite"
os.environ['GOOGLE_API_KEY'] = google_genai_api_key

# %%
import finnhub

# Setup client
finnhub_client = finnhub.Client(api_key=finnhub_io_api_key)

# Company News
# Need to use _from instead of from to avoid conflict
print(finnhub_client.company_news('AAPL', _from="2020-06-01", to="2025-06-10"))
# Out:
# []

# %%
print(finnhub_client.company_earnings('TSLA', limit=5))
# Out:
# [{'actual': 0.27, 'estimate': 0.399, 'period': '2025-03-31', 'quarter': 1, 'surprise': -0.129, 'surprisePercent': -32.3308, 'symbol': 'TSLA', 'year': 2025}, {'actual': 0.73, 'estimate': 0.7777, 'period': '2024-12-31', 'quarter': 4, 'surprise': -0.0477, 'surprisePercent': -6.1335, 'symbol': 'TSLA', 'year': 2024}, {'actual': 0.72, 'estimate': 0.5959, 'period': '2024-09-30', 'quarter': 3, 'surprise': 0.1241, 'surprisePercent': 20.8256, 'symbol': 'TSLA', 'year': 2024}, {'actual': 0.52, 'estimate': 0.6361, 'period': '2024-06-30', 'quarter': 2, 'surprise': -0.1161, 'surprisePercent': -18.2518, 'symbol': 'TSLA', 'year': 2024}]

# %%
print(finnhub_client.company_basic_financials('AAPL', 'all'))
# Out:
# {'metric': {'10DayAverageTradingVolume': 57.894, '13WeekPriceReturnDaily': 12.082, '26WeekPriceReturnDaily': -16.2807, '3MonthADReturnStd': 45.780865, '3MonthAverageTradingVolume': 59.99295, '52WeekHigh': 260.1, '52WeekHighDate': '2024-12-26', '52WeekLow': 169.2101, '52WeekLowDate': '2025-04-08', '52WeekPriceReturnDaily': -7.3216, '5DayPriceReturnDaily': -0.6119, 'assetTurnoverAnnual': 1.0714, 'assetTurnoverTTM': 1.1673, 'beta': 1.1067027, 'bookValuePerShareAnnual': 3.7673, 'bookValuePerShareQuarterly': 4.4712, 'bookValueShareGrowth5Y': -5.85, 'capexCagr5Y': -2.08, 'cashFlowPerShareAnnual': 7.1978, 'cashFlowPerShareQuarterly': 6.5924, 'cashFlowPerShareTTM': 6.86253, 'cashPerSharePerShareAnnual': 4.3112, 'cashPerSharePerShareQuarterly': 3.2463, 'currentDividendYieldTTM': 0.4907, 'currentEv/freeCashFlowAnnual': 29.3252, 'currentEv/freeCashFlowTTM': 32.3984, 'currentRatioAnnual': 0.8673, 'currentRatioQuarterly': 0.8209, 'dividendGrowthRate5Y': 5.3, 'dividendPerShareAnnual': 0.9935, 'div
# ...

# %%
# Company News
# Need to use _from instead of from to avoid conflict
print(finnhub_client.company_news('TSLA', _from="2023-05-01", to="2025-07-10"))
# Out:
# [{'category': 'company', 'datetime': 1752162153, 'headline': "Kevin O'Leary Says 'Trump And Elon Have To Get Back Together Again,' Praises Trump's Big Beautiful Bill", 'id': 135855568, 'image': 'https://s.yimg.com/rz/stage/p/yahoo_finance_en-US_h_p_finance_2.png', 'related': 'TSLA', 'source': 'Yahoo', 'summary': 'Kevin O’Leary is calling for Tesla (NASDAQ:TSLA) CEO Elon Musk and President Donald Trump to put aside their differences, saying their feud is hurting the country. In recent comments on Fox Business and social media, the businessman and investor made it clear he wants the two influential figures to reconcile. O’Leary Slams Third-Party Talk “Trump and Elon have to get back together again,” O’Leary wrote on X. “Frankly, I’m thinking of calling both up myself and saying, This is stupid. This is bad', 'url': 'https://finnhub.io/api/news?id=ec577e4806e0fd50027c45a6354b0f2a148c45553a7f38b97f1ac938543ea478'}, {'category': 'company', 'datetime': 1752161954, 'headline': 'Tesla Stock 
# ...

# %%
# Filings
print(finnhub_client.filings(symbol='AAPL', _from="2020-01-01", to="2020-06-11"))
# Out:
# [{'accessNumber': '0000320193-20-000056', 'symbol': 'AAPL', 'cik': '320193', 'form': '4', 'filedDate': '2020-05-12 00:00:00', 'acceptedDate': '2020-05-12 18:30:32', 'reportUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000056/wf-form4_158932261319105.xml', 'filingUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000056/0000320193-20-000056-index.html'}, {'accessNumber': '0001193125-20-139112', 'symbol': 'AAPL', 'cik': '320193', 'form': '8-K', 'filedDate': '2020-05-11 00:00:00', 'acceptedDate': '2020-05-11 16:31:15', 'reportUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000119312520139112/d926511d8k.htm', 'filingUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000119312520139112/0001193125-20-139112-index.html'}, {'accessNumber': '0001193125-20-133777', 'symbol': 'AAPL', 'cik': '320193', 'form': '424B2', 'filedDate': '2020-05-05 00:00:00', 'acceptedDate': '2020-05-05 16:31:51', 'reportUrl': 'https://www.sec.gov/Archives/edgar/data/320193/
# ...

# %%
import pandas as pd

# General news
# Fetch general news
news = finnhub_client.general_news('forex', min_id=0)
print (news)
# Convert the array of JSON to a pandas DataFrame
news_df = pd.DataFrame(news)

# Display the DataFrame as a table
print(news_df)
# Out:
# [{'category': 'forex', 'datetime': 1752167075, 'headline': 'US treasury sells 30 year bonds at a high yield of 4.889%.', 'id': 7496818, 'image': 'https://images.forexlive.com/fl-static/fl-thumbnail.jpg', 'related': '', 'source': 'Forexlive', 'summary': '<p>The US treasury sold $22 billion and 30 year bonds. The details:</p><ul><li>High-yield 4.889%</li><li>WI level at the time of the auction 4.8900%</li><li>Tail -0.1 basis points versus 6 month average of -0.3 basis points</li><li>directs 27.4% versus 6 month average of 23.1%</li><li>Indirects 59.78% versus 6 month average of 63.0%</li><li>Dealers 12.82% versus 6 month average of 13.9%</li></ul><p>Auction Grade B</p>\n                            This article was written by Greg Michalowski at www.forexlive.com.', 'url': 'https://www.forexlive.com/news/us-treasury-sells-30-year-bonds-at-a-high-yield-of-4889-20250710/'}]
#   category    datetime                                           headline  \
# ...

# %%
# IPO calendar
print(finnhub_client.ipo_calendar(_from="2025-01-01", to="2025-06-01"))
# Out:
# {'ipoCalendar': [{'date': '2025-05-30', 'exchange': 'NASDAQ Capital', 'name': 'Pitanium Ltd', 'numberOfShares': 1750000, 'price': '4.00', 'status': 'priced', 'symbol': 'PTNM', 'totalSharesValue': 7000000}, {'date': '2025-05-30', 'exchange': None, 'name': 'FG Merger III Corp.', 'numberOfShares': None, 'price': None, 'status': 'filed', 'symbol': '', 'totalSharesValue': 172500000}, {'date': '2025-05-30', 'exchange': None, 'name': 'Quantumsphere Acquisition Corp', 'numberOfShares': None, 'price': None, 'status': 'filed', 'symbol': 'QUMSU', 'totalSharesValue': 69000000}, {'date': '2025-05-30', 'exchange': None, 'name': 'Crown Reserve Acquisition Corp. I', 'numberOfShares': None, 'price': None, 'status': 'filed', 'symbol': 'CRACU', 'totalSharesValue': 172500000}, {'date': '2025-05-29', 'exchange': 'NYSE', 'name': 'JENA ACQUISITION Corp II', 'numberOfShares': 20000000, 'price': '10.00', 'status': 'priced', 'symbol': 'JENAU', 'totalSharesValue': 200000000}, {'date': '2025-05-29', 'exchange':
# ...

# %%
# Quote
print(finnhub_client.quote('AAPL'))
# Out:
# {'c': 212.61, 'd': 1.47, 'dp': 0.6962, 'h': 213.48, 'l': 210.03, 'o': 210.22, 'pc': 211.14, 't': 1752168409}

# %%
# Recommendation trends
print(finnhub_client.recommendation_trends('AAPL'))
# Out:
# [{'buy': 24, 'hold': 14, 'period': '2025-07-01', 'sell': 3, 'strongBuy': 14, 'strongSell': 1, 'symbol': 'AAPL'}, {'buy': 25, 'hold': 13, 'period': '2025-06-01', 'sell': 3, 'strongBuy': 15, 'strongSell': 1, 'symbol': 'AAPL'}, {'buy': 25, 'hold': 14, 'period': '2025-05-01', 'sell': 3, 'strongBuy': 14, 'strongSell': 0, 'symbol': 'AAPL'}, {'buy': 23, 'hold': 12, 'period': '2025-04-01', 'sell': 3, 'strongBuy': 12, 'strongSell': 1, 'symbol': 'AAPL'}]

# %%
from datetime import datetime

news = finnhub_client.company_news('TSLA', _from="2023-05-01", to="2025-07-10")
# extract datetime and headline keys from news which is list of JSON, covert dateime to date only and print headlines  sorted by datetime

# Extract datetime and headline
extracted_news = [(datetime.fromtimestamp(item['datetime']).date(), item['headline']) for item in news]

# Sort by datetime
sorted_news = sorted(extracted_news, key=lambda x: x[0])

# Print headlines
for date, headline in sorted_news:
    print(f"{date}: {headline}")
# Out:
# 2025-07-04: China's intense EV rivalry tests Thailand's local production goals
# 2025-07-04: Elon Musk's $71 Billion Wealth Wipeout Dwarfs Next 7 Billionaire Decliners Combined
# 2025-07-04: Elon Musk Backs Warren Buffett's Brutal '5-Minute Deficit Fix' To Ban Congress From Reelection If They Blow the Budget: '100% This Is the Way'
# 2025-07-04: Dow Jones Futures Fall, Trump Signs Budget Bill Into Law; Tesla Rival Uber Leads 5 Stocks In Buy Zones
# 2025-07-04: Mark Cuban And Elon Musk Have Something In Common Beyond Their Billions
# 2025-07-04: Behold, the epic flop that is the Cybertruck
# 2025-07-04: Tesla sales down 13.5% in Q2
# 2025-07-04: AGL acquires South Australia’s Virtual Power Plant from Telsa
# 2025-07-04: GM Beats Tesla in EV Growth, Reports 7% Jump in Overall Q2 Deliveries
# 2025-07-04: Navitas' GaN Power ICs Gaining Traction: What's Fueling It?
# 2025-07-04: Tesla Model Y loses title of best-selling car
# ...

# %%
# Extract headlines from sorted_news
sorted_news_headlines = [headline for _, headline in sorted_news]

# Display the list of headlines
print(sorted_news_headlines)
# Out:
# ["China's intense EV rivalry tests Thailand's local production goals", "Elon Musk's $71 Billion Wealth Wipeout Dwarfs Next 7 Billionaire Decliners Combined", "Elon Musk Backs Warren Buffett's Brutal '5-Minute Deficit Fix' To Ban Congress From Reelection If They Blow the Budget: '100% This Is the Way'", 'Dow Jones Futures Fall, Trump Signs Budget Bill Into Law; Tesla Rival Uber Leads 5 Stocks In Buy Zones', 'Mark Cuban And Elon Musk Have Something In Common Beyond Their Billions', 'Behold, the epic flop that is the Cybertruck', 'Tesla sales down 13.5% in Q2', 'AGL acquires South Australia’s Virtual Power Plant from Telsa', 'GM Beats Tesla in EV Growth, Reports 7% Jump in Overall Q2 Deliveries', "Navitas' GaN Power ICs Gaining Traction: What's Fueling It?", 'Tesla Model Y loses title of best-selling car', "Will Tesla's Worst-Ever Q2 Vehicle Sales Drop Shake its ETFs?", "I've Been Selling AI Stocks In The Name Of Value, But I Kept Tesla", 'Elon Musk Says He’s Forming ‘America Party’', '
# ...

# %%
# Convert sorted_news_headlines to a multiline string
sorted_news_headlines_multiline = "\n".join(sorted_news_headlines)

# Display the multiline string
print(sorted_news_headlines_multiline)
# Out:
# China's intense EV rivalry tests Thailand's local production goals
# Elon Musk's $71 Billion Wealth Wipeout Dwarfs Next 7 Billionaire Decliners Combined
# Elon Musk Backs Warren Buffett's Brutal '5-Minute Deficit Fix' To Ban Congress From Reelection If They Blow the Budget: '100% This Is the Way'
# Dow Jones Futures Fall, Trump Signs Budget Bill Into Law; Tesla Rival Uber Leads 5 Stocks In Buy Zones
# Mark Cuban And Elon Musk Have Something In Common Beyond Their Billions
# Behold, the epic flop that is the Cybertruck
# Tesla sales down 13.5% in Q2
# AGL acquires South Australia’s Virtual Power Plant from Telsa
# GM Beats Tesla in EV Growth, Reports 7% Jump in Overall Q2 Deliveries
# Navitas' GaN Power ICs Gaining Traction: What's Fueling It?
# Tesla Model Y loses title of best-selling car
# Will Tesla's Worst-Ever Q2 Vehicle Sales Drop Shake its ETFs?
# I've Been Selling AI Stocks In The Name Of Value, But I Kept Tesla
# Elon Musk Says He’s Forming ‘America Party’
# ...

# %%
# Get News 
from datetime import datetime
from datetime import datetime, timedelta

def get_sorted_news_headlines(ticker: str) -> str:
    """
    Fetches and processes news headlines for a given stock ticker within a 1-year date range.

    Args:
        ticker: The stock ticker symbol (e.g., 'TSLA').

    Returns:
        A multiline string of sorted news headlines.
    """
    # Compute date range
    today = datetime.now()
    one_year_ago = today - timedelta(days=365)
    _from = one_year_ago.strftime("%Y-%m-%d")
    to = today.strftime("%Y-%m-%d")

    # Fetch news
    news = finnhub_client.company_news(ticker, _from=_from, to=to)

    # Extract datetime and headline
    extracted_news = [(datetime.fromtimestamp(item['datetime']).date(), item['headline']) for item in news]

    # Sort by datetime
    sorted_news = sorted(extracted_news, key=lambda x: x[0])

    # Extract headlines from sorted_news
    sorted_news_headlines = [headline for _, headline in sorted_news]

    # Convert sorted_news_headlines to a multiline string
    sorted_news_headlines_multiline = "\n".join(sorted_news_headlines)

    return sorted_news_headlines_multiline

# Example usage
print(get_sorted_news_headlines('TSLA'))
# Out:
# China's intense EV rivalry tests Thailand's local production goals
# Elon Musk's $71 Billion Wealth Wipeout Dwarfs Next 7 Billionaire Decliners Combined
# Elon Musk Backs Warren Buffett's Brutal '5-Minute Deficit Fix' To Ban Congress From Reelection If They Blow the Budget: '100% This Is the Way'
# Dow Jones Futures Fall, Trump Signs Budget Bill Into Law; Tesla Rival Uber Leads 5 Stocks In Buy Zones
# Mark Cuban And Elon Musk Have Something In Common Beyond Their Billions
# Behold, the epic flop that is the Cybertruck
# Tesla sales down 13.5% in Q2
# AGL acquires South Australia’s Virtual Power Plant from Telsa
# GM Beats Tesla in EV Growth, Reports 7% Jump in Overall Q2 Deliveries
# Navitas' GaN Power ICs Gaining Traction: What's Fueling It?
# Tesla Model Y loses title of best-selling car
# I've Been Selling AI Stocks In The Name Of Value, But I Kept Tesla
# Elon Musk Says He’s Forming ‘America Party’
# The Volkswagen Robotaxi That Wants to Rival Waymo and Tesla
# ...

# %%
# Define the prompt
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.schema import HumanMessage

def analyze_stock_sentiment(stock_symbol: str, news_article: str) -> str:
    """
    Analyzes the sentiment of a news article related to a specific stock.

    Args:
        stock_symbol: The ticker symbol of the stock (e.g., "CRCL").
        news_article: The text of the news article.

    Returns:
        A string indicating the sentiment (positive, negative, or neutral).
    """
    llm = ChatGoogleGenerativeAI(model=google_gemini_model) # Use a suitable Gemini model
    prompt = f"""
    You are an expert financial analyst. Your task is to analyze the sentiment of the following news article related to the stock {stock_symbol}.
    Determine if the overall sentiment is positive, negative, or neutral. 
    Provide the sentiment (positive, negative, or neutral) as well as recent news that let to specific sentiment in the output.
    Also state the reason for your sentiment analysis conclusion.
    Also provide long term outlook for the stock based on the news article and historical gain or loss since last 20 year or inception.

    News Article:
    {news_article}

    """

    messages = [HumanMessage(content=prompt)]
    response = llm.invoke(messages)
    return response.content

# %%
# Capture the output in a variable and write onconsole in seperated lines
def get_stock_sentiment_output(ticker: str) -> str:
    """
    Analyzes the sentiment of a stock based on its news headlines and returns the output.

    Args:
        ticker: The stock ticker symbol (e.g., 'TSLA').

    Returns:
        A string containing the sentiment analysis output.
    """
    output = analyze_stock_sentiment(ticker, get_sorted_news_headlines(ticker))
    return output

# %%
ticker='NVDA'
output = get_stock_sentiment_output(ticker)

# Write the output to the console with each line on a separate line
for line in output.split('\n'):
    print(line)
# Out:
# **Sentiment:** Positive
#
# **Reasons:**
#
# The overwhelming sentiment surrounding NVDA is positive, driven by several key factors:
#
# *   **$4 Trillion Market Cap Milestone:** Numerous articles highlight Nvidia's achievement of reaching a $4 trillion market capitalization, a historic first. This signifies immense market confidence and dominance.
# *   **AI Dominance:** The articles consistently emphasize Nvidia's leading position in the AI market, with mentions of its chips powering AI infrastructure, sovereign AI initiatives, and data center investments.
# *   **Analyst Upgrades and Positive Ratings:** Many analysts have issued "Buy" ratings and raised price targets for NVDA, reflecting strong confidence in its future growth.
# *   **Strong Performance and Market Outperformance:** The stock's rise, particularly its outperformance of the broader market, is a recurring theme, indicating investor enthusiasm.
# ...
