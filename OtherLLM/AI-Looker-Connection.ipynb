# %%
# !pip install google-genai
# !pip install langchain 
# !pip install langchain_google_genai
# !pip install langchain_looker_agent
# !pip install looker-sdk

# %%
import os
api_key="AIzaSyBF8HNZEA32-CemMk-EfhlrF7Jbwsuj_tM"
os.environ['GOOGLE_API_KEY'] = api_key

# %%
from langchain_looker_agent import create_looker_sql_agent, LookerSQLDatabase
from langchain_google_genai import ChatGoogleGenerativeAI
import os

os.environ['LOOKER_BASE_URL'] = "https://your-looker-instance.looker.com" # Replace with your Looker instance URL
os.environ['LOOKML_MODEL_NAME'] = "your_lookml_model_name"  # Replace with your LookML model name
os.environ['LOOKER_CLIENT_ID'] = "your_looker_client_id"  # Replace with your Looker client ID  
os.environ['LOOKER_CLIENT_SECRET'] = "your_looker_client_secret"  # Replace with your Looker client secret
os.environ['JDBC_DRIVER_PATH'] = "/path/to/your/jdbc/driver.jar"  # Replace with the path to your JDBC driver   

# Initialize Looker connection
looker_db = LookerSQLDatabase(
    looker_instance_url=os.getenv('LOOKER_BASE_URL'),
    lookml_model_name=os.getenv('LOOKML_MODEL_NAME'),
    client_id=os.getenv('LOOKER_CLIENT_ID'),
    client_secret=os.getenv('LOOKER_CLIENT_SECRET'),
    jdbc_driver_path=os.getenv('JDBC_DRIVER_PATH')
)

# Create the agent
llm = ChatGoogleGenerativeAI(model="gemini-2.5-pro") # Use a suitable Gemini model
toolkit = LookerSQLToolkit(db=looker_db, llm=llm)
agent = create_looker_sql_agent(llm=llm, toolkit=toolkit)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 6
#       3 import os
#       5 # Initialize Looker connection
# ----> 6 looker_db = LookerSQLDatabase(
#       7     looker_instance_url=os.getenv('LOOKER_BASE_URL'),
#       8     lookml_model_name=os.getenv('LOOKML_MODEL_NAME'),
#       9     client_id=os.getenv('LOOKER_CLIENT_ID'),
#      10     client_secret=os.getenv('LOOKER_CLIENT_SECRET'),
#      11     jdbc_driver_path=os.getenv('JDBC_DRIVER_PATH')
#      12 )
#      14 # Create the agent
#      15 llm = ChatGoogleGenerativeAI(model="gemini-2.5-pro") # Use a suitable Gemini model
#
# ...
