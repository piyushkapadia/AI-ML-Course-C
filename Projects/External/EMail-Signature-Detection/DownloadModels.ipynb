# %%
from huggingface_hub import snapshot_download

snapshot_download(repo_id="bert-base-uncased")

huggingface-cli download bert-base-uncased

huggingface-cli download bert-base-uncased --local-dir D:\Dev\GitHub\AI-ML-Course\Projects\External\EMail-Signature-Detection\models --cache-dir D:\Dev\GitHub\AI-ML-Course\Projects\External\EMail-Signature-Detection\cache
