# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly as plt

# %%
df = pd.read_csv('D:/Dev/AI-ML-Material/CaseStudies/Uber/Uber_Data.csv')

# %%
df.describe().T
#df.describe()
df.describe(all)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 df.describe().T
#       2 #df.describe()
# ----> 3 df.describe(all)
#
# File d:\Dev\Tools\Python\Python312\Lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
df.head()
# Out:
#           pickup_dt    borough  pickups  spd   vsb  temp  dewp     slp  pcp01  \
# 0  01-01-2015 01:00      Bronx      152  5.0  10.0  30.0   7.0  1023.5    0.0
# 1  01-01-2015 01:00   Brooklyn     1519  5.0  10.0   NaN   7.0  1023.5    0.0
# 2  01-01-2015 01:00        EWR        0  5.0  10.0  30.0   7.0  1023.5    0.0
# 3  01-01-2015 01:00  Manhattan     5258  5.0  10.0  30.0   7.0  1023.5    0.0
# 4  01-01-2015 01:00     Queens      405  5.0  10.0  30.0   7.0  1023.5    0.0
#
#    pcp06  pcp24   sd hday
# 0    0.0    0.0  0.0    Y
# 1    0.0    0.0  0.0    Y
# 2    0.0    0.0  0.0    Y
# 3    0.0    0.0  0.0    Y
# 4    0.0    0.0  0.0    Y

# %%
df['borough'].unique()
df['hday'].value_counts(normalize=True)
df['hday'].value_counts(dropna=False)
# Out:
# hday
# N    27980
# Y     1121
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (29101, 13)

# %%
df['pickup_dt'] = pd.to_datetime(df['pickup_dt'], format="%d-%m-Y %H:%M")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['pickup_dt'] = pd.to_datetime(df['pickup_dt'], format="%d-%m-Y %H:%M")
#
# File d:\Dev\Tools\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File d:\Dev\Tools\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# ...

# %%
df.loc[df['temp'].isnull()==True]
# Out:
#              pickup_dt   borough  pickups  spd   vsb  temp  dewp     slp  \
# 1     01-01-2015 01:00  Brooklyn     1519  5.0  10.0   NaN   7.0  1023.5
# 8     01-01-2015 02:00  Brooklyn     1229  3.0  10.0   NaN   6.0  1023.0
# 15    01-01-2015 03:00  Brooklyn     1601  5.0  10.0   NaN   8.0  1022.3
# 22    01-01-2015 04:00  Brooklyn     1390  5.0  10.0   NaN   9.0  1022.0
# 29    01-01-2015 05:00  Brooklyn      759  5.0  10.0   NaN   9.0  1021.8
# ...                ...       ...      ...  ...   ...   ...   ...     ...
# 2334  15-01-2015 19:00  Brooklyn      594  5.0  10.0   NaN  13.0  1016.2
# 2340  15-01-2015 20:00  Brooklyn      620  5.0  10.0   NaN  13.0  1015.5
# 2347  15-01-2015 21:00  Brooklyn      607  3.0  10.0   NaN  14.0  1015.4
# 2354  15-01-2015 22:00  Brooklyn      648  9.0  10.0   NaN  14.0  1015.4
# 2361  15-01-2015 23:00  Brooklyn      602  5.0  10.0   NaN  16.0  1015.4
#
#       pcp01  pcp06  pcp24   sd hday
# 1       0.0    0.0    0.0  0.0    Y
# ...
